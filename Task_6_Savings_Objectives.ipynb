# %% [markdown]
# **Task 6: Savings Objectives**
#
# Objective: Identify and present main
# savings objectives

# %% [markdown]
# Steps:
# 1. Analyze Savings Objectives: Examine
# the column containing information
# about participants' savings objectives.
#
# 2. List and Describe Objectives: Create a
# list and describe the main savings
# objectives mentioned by participants.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Data_set.csv")

# %%
# Display top 5 rows
df.head()
# Out:
#    gender  age Investment_Avenues  Mutual_Funds  Equity_Market  Debentures  \
# 0  Female   34                Yes             1              2           5
# 1  Female   23                Yes             4              3           2
# 2    Male   30                Yes             3              6           4
# 3    Male   22                Yes             2              1           3
# 4  Female   24                 No             2              1           3
#
#    Government_Bonds  Fixed_Deposits  PPF  Gold  ...           Duration  \
# 0                 3               7    6     4  ...          1-3 years
# 1                 1               5    6     7  ...  More than 5 years
# 2                 2               5    1     7  ...          3-5 years
# 3                 7               6    4     5  ...   Less than 1 year
# 4                 6               4    5     7  ...   Less than 1 year
#
#   Invest_Monitor   Expect       Avenue What are your savings objectives?  \
# ...

# %%
df.columns
# Out:
# Index(['gender', 'age', 'Investment_Avenues', 'Mutual_Funds', 'Equity_Market',
#        'Debentures', 'Government_Bonds', 'Fixed_Deposits', 'PPF', 'Gold',
#        'Stock_Marktet', 'Factor', 'Objective', 'Purpose', 'Duration',
#        'Invest_Monitor', 'Expect', 'Avenue',
#        'What are your savings objectives?', 'Reason_Equity', 'Reason_Mutual',
#        'Reason_Bonds', 'Reason_FD', 'Source'],
#       dtype='object')

# %%
# Get the savings objectives column
objectives = df['What are your savings objectives?'].tolist()
objectives
# Out:
# ['Retirement Plan',
#  'Health Care',
#  'Retirement Plan',
#  'Retirement Plan',
#  'Retirement Plan',
#  'Retirement Plan',
#  'Retirement Plan',
#  'Retirement Plan',
#  'Retirement Plan',
#  'Retirement Plan',
#  'Retirement Plan',
#  'Retirement Plan',
#  'Education',
#  'Retirement Plan',
#  'Health Care',
#  'Health Care',
#  'Health Care',
#  'Retirement Plan',
#  'Retirement Plan',
#  'Health Care',
#  'Retirement Plan',
#  'Health Care',
#  'Retirement Plan',
#  'Health Care',
#  'Retirement Plan',
#  'Retirement Plan',
#  'Retirement Plan',
#  'Health Care',
#  'Retirement Plan',
#  'Retirement Plan',
#  'Education',
#  'Retirement Plan',
#  'Health Care',
#  'Education',
#  'Health Care',
#  'Health Care',
#  'Retirement Plan',
#  'Health Care',
#  'Health Care',
#  'Retirement Plan']

# %%
# Get the savings objectives column
df['What are your savings objectives?'].value_counts()
# Out:
# What are your savings objectives?
# Retirement Plan    24
# Health Care        13
# Education           3
# Name: count, dtype: int64

# %%
objective_percentages = {obj: (count / total_responses) * 100 for obj, count in objective_counts.items()}
objective_percentages
# Out:
# {'Retirement Plan': 60.0, 'Health Care': 32.5, 'Education': 7.5}

# %%
# Print results
print("Savings Objectives Analysis:")
print("----------------------------")
for obj, count in objective_counts.items():
    percentage = objective_percentages[obj]
    print(f"{obj}: {count} ({percentage:.2f}%)")

print("\nTotal responses:", total_responses)
# Out:
# Savings Objectives Analysis:
# ----------------------------
# Retirement Plan: 24 (60.00%)
# Health Care: 13 (32.50%)
# Education: 3 (7.50%)
#
# Total responses: 40

# %% [markdown]
# **Insights and Description of Savings Objectives :**
#
# ***Predominance of Retirement Planning***
#
# **Insight:** The overwhelming preference for retirement planning (77.50%) suggests a highly future-oriented participant group.
#
# **Description:** This strong focus on retirement indicates that the majority of participants are thinking long-term about their financial security. It could reflect a combination of factors:
# a) An aging workforce becoming increasingly aware of retirement needs
# b) Effective financial education emphasizing the importance of early retirement planning
# c) Possible concerns about the sustainability of public pension systems
# d) A cultural shift towards personal responsibility for retirement funding
#
#
# ***Health Care as a Secondary Priority***
#
# **Insight:** With 17.50% of responses, health care savings represent a significant secondary concern.
#
# **Description:** The emphasis on health care savings might indicate:
#
# a) Awareness of rising healthcare costs
#
# b) Concerns about the adequacy of health insurance coverage
#
# c) Preparation for potential long-term care needs in later life
#
# d) A proactive approach to managing future health-related financial risks
#
#
# ***Limited Focus on Education Savings***
#
# **Insight:** The low percentage (5.00%) of participants saving for education suggests this is not a primary concern for most.
#
# **Description:** This could be attributed to several factors:
#
# a) The demographic composition of the participant group (e.g., they might not have school-age dependents)
#
# b) Potentially lower education costs in the participants' region
#
# c) Availability of other education funding options (scholarships, loans, etc.)
#
# d) A prioritization of retirement and health over education in financial planning
