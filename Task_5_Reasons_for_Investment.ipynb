# %% [markdown]
# **Task 5: Reasons for Investment**
#
# Objective : Analyze and summarize reasons
# for investment choices.

# %% [markdown]
# Steps:
# 1. Explore Reasons Column: Investigate
# the column where participants
# provided reasons for their investment
# choices.
#
# 2. Summarize Reasons: Identify common
# themes or recurring reasons and
# provide a summary.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Data_set.csv")

# %%
# Display top 5 rows
df.head()
# Out:
#    gender  age Investment_Avenues  Mutual_Funds  Equity_Market  Debentures  \
# 0  Female   34                Yes             1              2           5
# 1  Female   23                Yes             4              3           2
# 2    Male   30                Yes             3              6           4
# 3    Male   22                Yes             2              1           3
# 4  Female   24                 No             2              1           3
#
#    Government_Bonds  Fixed_Deposits  PPF  Gold  ...           Duration  \
# 0                 3               7    6     4  ...          1-3 years
# 1                 1               5    6     7  ...  More than 5 years
# 2                 2               5    1     7  ...          3-5 years
# 3                 7               6    4     5  ...   Less than 1 year
# 4                 6               4    5     7  ...   Less than 1 year
#
#   Invest_Monitor   Expect       Avenue What are your savings objectives?  \
# ...

# %%
# Explore the reasons columns (e.g., 'Reason_Equity', 'Reason_Mutual')
df = (df[['Reason_Equity', 'Reason_Mutual', 'Reason_Bonds']].head())
df
# Out:
#           Reason_Equity         Reason_Mutual     Reason_Bonds
# 0  Capital Appreciation        Better Returns  Safe Investment
# 1              Dividend        Better Returns  Safe Investment
# 2  Capital Appreciation          Tax Benefits  Assured Returns
# 3              Dividend  Fund Diversification   Tax Incentives
# 4  Capital Appreciation        Better Returns  Safe Investment

# %%
df['Investment_Avenues'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3790         try:
# -> 3791             return self._engine.get_loc(casted_key)
#    3792         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Investment_Avenues'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-fe5cee3caf9d> in <cell line: 1>()
# ----> 1 df['Investment_Avenues'].value_counts()
#
# ...

# %%
# Get unique values in the Investment_Avenues column
unique_investment_avenues = df['Investment_Avenues'].unique()

# Display the unique values
print("Unique values in Investment Avenues:")
print(unique_investment_avenues)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3790         try:
# -> 3791             return self._engine.get_loc(casted_key)
#    3792         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Investment_Avenues'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-0943f973b951> in <cell line: 2>()
#       1 # Get unique values in the Investment_Avenues column
# ...

# %%
# Analyze reasons for each type of investment
equity_reasons = df['Reason_Equity'].value_counts()
equity_reasons
# Out:
# Reason_Equity
# Capital Appreciation    3
# Dividend                2
# Name: count, dtype: int64

# %%
mutual_fund_reasons = df['Reason_Mutual'].value_counts()
mutual_fund_reasons
# Out:
# Reason_Mutual
# Better Returns          3
# Tax Benefits            1
# Fund Diversification    1
# Name: count, dtype: int64

# %%
bonds_reasons = df['Reason_Bonds'].value_counts()
bonds_reasons
# Out:
# Reason_Bonds
# Safe Investment    3
# Assured Returns    1
# Tax Incentives     1
# Name: count, dtype: int64

# %% [markdown]
# * Most people invest in equity for capital appreciation.
# * The majority of mutual fund investors seek better returns.
# * Investors in bonds often prioritize safety or assured returns.

# %% [markdown]
# * Safety: Many participants may prioritize the safety of their investments.
# * Capital Appreciation: Investors might be looking for growth in the value of their investments.
# * Tax Savings: Some may invest for tax benefits.
# * Liquidity: Easy access to funds could be a reason for choosing certain avenues.
